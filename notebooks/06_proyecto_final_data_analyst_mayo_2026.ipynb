# %% [markdown]
# # 06_proyecto_final_data_analyst_mayo_2026
#
# **Mayo 2026 · Bloque Proyecto**
#
# ## Objetivos
# - Integrar EDA, modelado, evaluación y comunicación
# - Generar un informe técnico reproducible

# %% [markdown]
# ## Preparación
# Ejecuta la primera celda para cargar librerías. Si falta alguna librería, instálala desde el entorno con `pip install -r requirements.txt`.

# %% [markdown]
# ## Plantilla del proyecto

# %%
import warnings
warnings.filterwarnings("ignore")

from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

DATA_DIR = Path("../datasets")
pd.set_option("display.max_columns", 50)

# 1. Define tu pregunta analítica
# 2. Carga el dataset
# 3. Limpia y transforma variables
# 4. Entrena/evalúa un modelo si aplica
# 5. Presenta conclusiones y limitaciones
print("Plantilla lista para completar.")

# %% [markdown]
# ## Actividad entregable
# 1. Modifica el dataset o hiperparámetros.
# 2. Añade una breve interpretación de resultados.
# 3. Guarda el notebook ejecutado y exporta una versión HTML/PDF si se solicita.
